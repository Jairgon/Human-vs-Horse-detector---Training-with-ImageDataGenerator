# %% [markdown]
# ### Human vs Horse detector - Training with ImageDataGenerator
#
# In this project a model will be trained which will differentiate an image between whether it is a horse or a person. There are 1000 images for training and 256 for validation with different sizes and positions.
#
# Here we explicitly do not have a label for each image, so we will use the [ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator) API instead. and it will automatically do the label for us.

# %%
import zipfile

# Unzip the dataset for Train and Validation
local_zip = './horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./horse-or-human')


# Unzip validation set
local_zip = './validation-horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./validation-horse-or-human')

zip_ref.close()

# %%
import os

# Directory the datasets
train_horse_dir = os.path.join('./horse-or-human/horses')

train_human_dir = os.path.join('./horse-or-human/humans')

validation_horse_dir = os.path.join('./validation-horse-or-human/horses')

validation_human_dir = os.path.join('./validation-horse-or-human/humans')

# %% [markdown]
# Below are some names of the images grouped in the different training and validation sets.

# %%
train_horse_names = os.listdir(train_horse_dir)
print(f'TRAIN SET HORSES: {train_horse_names[:5]}')

train_human_names = os.listdir(train_human_dir)
print(f'TRAIN SET HUMANS: {train_human_names[:5]}')

validation_horse_names = os.listdir(validation_horse_dir)
print(f'VAL SET HORSES: {validation_horse_names[:5]}')

validation_human_names = os.listdir(validation_human_dir)
print(f'VAL SET HUMANS: {validation_human_names[:5]}')
# Out:
# TRAIN SET HORSES: ['horse18-7.png', 'horse27-2.png', 'horse50-7.png', 'horse44-6.png', 'horse44-7.png']
# TRAIN SET HUMANS: ['human17-30.png', 'human17-02.png', 'human11-10.png', 'human17-29.png', 'human09-14.png']
# VAL SET HORSES: ['horse5-478.png', 'horse5-360.png', 'horse6-161.png', 'horse1-298.png', 'horse2-040.png']
# VAL SET HUMANS: ['valhuman05-21.png', 'valhuman03-22.png', 'valhuman01-06.png', 'valhuman04-22.png', 'valhuman05-12.png']

# %% [markdown]
# In total there are a number of images of:

# %%
print(f'total training horse images: {len(os.listdir(train_horse_dir))}')
print(f'total training human images: {len(os.listdir(train_human_dir))}')
print(f'total validation horse images: {len(os.listdir(validation_horse_dir))}')
print(f'total validation human images: {len(os.listdir(validation_human_dir))}')
# Out:
# total training horse images: 500
# total training human images: 527
# total validation horse images: 128
# total validation human images: 128

# %% [markdown]
# A sample of the type of images used in this project is shown below.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 4
next_horse_pix = [os.path.join(train_horse_dir, fname) 
                for fname in train_horse_names[pic_index-4:pic_index]]
next_human_pix = [os.path.join(train_human_dir, fname) 
                for fname in train_human_names[pic_index-4:pic_index]]

for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Convolutional Model
#
# As a model, a convolutional network will be used, which will work together with different pooling layers.

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential([
    # te disired size is 150 x 150 and in color(3)
    tf.keras.layers.Conv2D(16,(3,3),activation='relu',input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
    
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 148, 148, 16)      448
#
#  max_pooling2d_15 (MaxPoolin  (None, 74, 74, 16)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 72, 72, 32)        4640
#
#  max_pooling2d_16 (MaxPoolin  (None, 36, 36, 32)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 34, 34, 64)        18496
#
#  max_pooling2d_17 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 18496)             0
#
#  dense_6 (Dense)             (None, 512)               9470464
#
#  dense_7 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The "output shape" column shows how the size of your feature map evolves in each successive layer. Here you see how the convolution layers removes the outermost pixels of the image, and each pooling layer halves the dimensions.

# %% [markdown]
# # PRE PROCESSING

# %% [markdown]
# Next, the *generator* is used to resize all the images in a size of 300x300 and place their respective label (horse or human). An additional process will be to normalize the images so that the pixel values ​​are between [0,1]

# %% [markdown]
# In Keras, this can be done via the keras.preprocessing.image.ImageDataGenerator class using the rescale parameter. This ImageDataGenerator class allows you to instantiate generators of augmented image batches (and their labels) via .flow(data, labels) or .flow_from_directory(directory)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        './horse-or-human/',  
        target_size=(150, 150),  
        batch_size=128,
        # Since you use binary_crossentropy loss,need binary labels
        class_mode='binary')

validation_generator = validation_datagen.flow_from_directory(
        './validation-horse-or-human/', 
        target_size=(150, 150),  
        batch_size=32,
        class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.

# %% [markdown]
# ## OPTIMIZER
#
# In order to find the best learning rate for the model, a comparison is made between different loss values with different learning rates, looking for the one that provides the least value.

# %%
from tensorflow.keras.optimizers import RMSprop

lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = RMSprop(learning_rate=1e-8)

model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=["accuracy"])

history = model.fit(
      train_generator,
      steps_per_epoch=8,  
      epochs=120,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks=[lr_schedule])
# Out:
# Epoch 1/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6863 - accuracy: 0.5184 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-08
# Epoch 2/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6848 - accuracy: 0.5306 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.1220e-08
# Epoch 3/120
# 8/8 [==============================] - 8s 994ms/step - loss: 0.6834 - accuracy: 0.5339 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.2589e-08
# Epoch 4/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6869 - accuracy: 0.5228 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.4125e-08
# Epoch 5/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6840 - accuracy: 0.5328 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.5849e-08
# Epoch 6/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6844 - accuracy: 0.5273 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.7783e-08
# Epoch 7/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6853 - accuracy: 0.5261 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.9953e-08
# Epoch 8/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6870 - accuracy: 0.5228 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.2387e-08
# Epoch 9/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6884 - accuracy: 0.5184 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.5119e-08
# Epoch 10/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6851 - accuracy: 0.5273 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.8184e-08
# Epoch 11/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6852 - accuracy: 0.5283 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 3.1623e-08
# Epoch 12/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6842 - accuracy: 0.5306 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 3.5481e-08
# Epoch 13/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6859 - accuracy: 0.5206 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 3.9811e-08
# Epoch 14/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6859 - accuracy: 0.5206 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 4.4668e-08
# Epoch 15/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6877 - accuracy: 0.5184 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 5.0119e-08
# Epoch 16/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6850 - accuracy: 0.5295 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 5.6234e-08
# Epoch 17/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6850 - accuracy: 0.5306 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 6.3096e-08
# Epoch 18/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6838 - accuracy: 0.5306 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 7.0795e-08
# Epoch 19/120
# 8/8 [==============================] - 8s 1s/step - loss: 0.6878 - accuracy: 0.5217 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 7.9433e-08
# Epoch 20/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6865 - accuracy: 0.5250 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 8.9125e-08
# Epoch 21/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6879 - accuracy: 0.5217 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-07
# Epoch 22/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6857 - accuracy: 0.5217 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.1220e-07
# Epoch 23/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6843 - accuracy: 0.5317 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.2589e-07
# Epoch 24/120
# 8/8 [==============================] - 8s 1s/step - loss: 0.6823 - accuracy: 0.5384 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.4125e-07
# Epoch 25/120
# 8/8 [==============================] - 8s 986ms/step - loss: 0.6835 - accuracy: 0.5339 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.5849e-07
# Epoch 26/120
# 8/8 [==============================] - 8s 1s/step - loss: 0.6847 - accuracy: 0.5284 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.7783e-07
# Epoch 27/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6850 - accuracy: 0.5264 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.9953e-07
# Epoch 28/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6856 - accuracy: 0.5254 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.2387e-07
# Epoch 29/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6860 - accuracy: 0.5264 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.5119e-07
# Epoch 30/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6872 - accuracy: 0.5172 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.8184e-07
# Epoch 31/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6832 - accuracy: 0.5328 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 3.1623e-07
# Epoch 32/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6853 - accuracy: 0.5284 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 3.5481e-07
# Epoch 33/120
# 8/8 [==============================] - 8s 1s/step - loss: 0.6845 - accuracy: 0.5284 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 3.9811e-07
# Epoch 34/120
# 8/8 [==============================] - 9s 994ms/step - loss: 0.6831 - accuracy: 0.5373 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 4.4668e-07
# Epoch 35/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6861 - accuracy: 0.5206 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 5.0119e-07
# Epoch 36/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6854 - accuracy: 0.5339 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 5.6234e-07
# Epoch 37/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6869 - accuracy: 0.5261 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 6.3096e-07
# Epoch 38/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6854 - accuracy: 0.5250 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 7.0795e-07
# Epoch 39/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6854 - accuracy: 0.5264 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 7.9433e-07
# Epoch 40/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6860 - accuracy: 0.5250 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 8.9125e-07
# Epoch 41/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6860 - accuracy: 0.5250 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.0000e-06
# Epoch 42/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6866 - accuracy: 0.5217 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.1220e-06
# Epoch 43/120
# 8/8 [==============================] - 11s 2s/step - loss: 0.6850 - accuracy: 0.5295 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.2589e-06
# Epoch 44/120
# 8/8 [==============================] - 15s 2s/step - loss: 0.6852 - accuracy: 0.5273 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.4125e-06
# Epoch 45/120
# 8/8 [==============================] - 14s 2s/step - loss: 0.6846 - accuracy: 0.5261 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.5849e-06
# Epoch 46/120
# 8/8 [==============================] - 17s 2s/step - loss: 0.6856 - accuracy: 0.5261 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.7783e-06
# Epoch 47/120
# 8/8 [==============================] - 17s 2s/step - loss: 0.6872 - accuracy: 0.5161 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 1.9953e-06
# Epoch 48/120
# 8/8 [==============================] - 18s 2s/step - loss: 0.6880 - accuracy: 0.5217 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.2387e-06
# Epoch 49/120
# 8/8 [==============================] - 19s 2s/step - loss: 0.6870 - accuracy: 0.5161 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.5119e-06
# Epoch 50/120
# 8/8 [==============================] - 16s 2s/step - loss: 0.6851 - accuracy: 0.5273 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 2.8184e-06
# Epoch 51/120
# 8/8 [==============================] - 15s 2s/step - loss: 0.6839 - accuracy: 0.5328 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 3.1623e-06
# Epoch 52/120
# 8/8 [==============================] - 15s 2s/step - loss: 0.6881 - accuracy: 0.5150 - val_loss: 0.6931 - val_accuracy: 0.5000 - lr: 3.5481e-06
# Epoch 53/120
# 8/8 [==============================] - 15s 2s/step - loss: 0.6853 - accuracy: 0.5264 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 3.9811e-06
# Epoch 54/120
# 8/8 [==============================] - 14s 2s/step - loss: 0.6826 - accuracy: 0.5406 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 4.4668e-06
# Epoch 55/120
# 8/8 [==============================] - 16s 2s/step - loss: 0.6851 - accuracy: 0.5273 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 5.0119e-06
# Epoch 56/120
# 8/8 [==============================] - 14s 2s/step - loss: 0.6872 - accuracy: 0.5228 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 5.6234e-06
# Epoch 57/120
# 8/8 [==============================] - 14s 2s/step - loss: 0.6836 - accuracy: 0.5261 - val_loss: 0.6930 - val_accuracy: 0.5000 - lr: 6.3096e-06
# Epoch 58/120
# 8/8 [==============================] - 12s 1s/step - loss: 0.6857 - accuracy: 0.5195 - val_loss: 0.6929 - val_accuracy: 0.5000 - lr: 7.0795e-06
# Epoch 59/120
# 8/8 [==============================] - 12s 1s/step - loss: 0.6840 - accuracy: 0.5317 - val_loss: 0.6929 - val_accuracy: 0.5000 - lr: 7.9433e-06
# Epoch 60/120
# 8/8 [==============================] - 14s 2s/step - loss: 0.6837 - accuracy: 0.5328 - val_loss: 0.6929 - val_accuracy: 0.5000 - lr: 8.9125e-06
# Epoch 61/120
# 8/8 [==============================] - 14s 2s/step - loss: 0.6834 - accuracy: 0.5317 - val_loss: 0.6929 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 62/120
# 8/8 [==============================] - 13s 2s/step - loss: 0.6868 - accuracy: 0.5273 - val_loss: 0.6929 - val_accuracy: 0.5000 - lr: 1.1220e-05
# Epoch 63/120
# 8/8 [==============================] - 13s 2s/step - loss: 0.6847 - accuracy: 0.5306 - val_loss: 0.6929 - val_accuracy: 0.5000 - lr: 1.2589e-05
# Epoch 64/120
# 8/8 [==============================] - 14s 2s/step - loss: 0.6853 - accuracy: 0.5172 - val_loss: 0.6929 - val_accuracy: 0.5000 - lr: 1.4125e-05
# Epoch 65/120
# 8/8 [==============================] - 18s 2s/step - loss: 0.6849 - accuracy: 0.5250 - val_loss: 0.6929 - val_accuracy: 0.5000 - lr: 1.5849e-05
# Epoch 66/120
# 8/8 [==============================] - 14s 2s/step - loss: 0.6853 - accuracy: 0.5228 - val_loss: 0.6928 - val_accuracy: 0.5000 - lr: 1.7783e-05
# Epoch 67/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6838 - accuracy: 0.5273 - val_loss: 0.6928 - val_accuracy: 0.5000 - lr: 1.9953e-05
# Epoch 68/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6803 - accuracy: 0.5417 - val_loss: 0.6928 - val_accuracy: 0.5000 - lr: 2.2387e-05
# Epoch 69/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6819 - accuracy: 0.5350 - val_loss: 0.6927 - val_accuracy: 0.5000 - lr: 2.5119e-05
# Epoch 70/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6847 - accuracy: 0.5239 - val_loss: 0.6928 - val_accuracy: 0.5000 - lr: 2.8184e-05
# Epoch 71/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.6849 - accuracy: 0.5273 - val_loss: 0.6927 - val_accuracy: 0.5000 - lr: 3.1623e-05
# Epoch 72/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6850 - accuracy: 0.5239 - val_loss: 0.6926 - val_accuracy: 0.5000 - lr: 3.5481e-05
# Epoch 73/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6855 - accuracy: 0.5217 - val_loss: 0.6925 - val_accuracy: 0.5000 - lr: 3.9811e-05
# Epoch 74/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.6829 - accuracy: 0.5317 - val_loss: 0.6923 - val_accuracy: 0.5000 - lr: 4.4668e-05
# Epoch 75/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.6857 - accuracy: 0.5184 - val_loss: 0.6922 - val_accuracy: 0.5000 - lr: 5.0119e-05
# Epoch 76/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.6850 - accuracy: 0.5317 - val_loss: 0.6922 - val_accuracy: 0.5000 - lr: 5.6234e-05
# Epoch 77/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.6850 - accuracy: 0.5261 - val_loss: 0.6920 - val_accuracy: 0.5000 - lr: 6.3096e-05
# Epoch 78/120
# 8/8 [==============================] - 11s 2s/step - loss: 0.6822 - accuracy: 0.5328 - val_loss: 0.6918 - val_accuracy: 0.5000 - lr: 7.0795e-05
# Epoch 79/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6844 - accuracy: 0.5284 - val_loss: 0.6917 - val_accuracy: 0.5000 - lr: 7.9433e-05
# Epoch 80/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6831 - accuracy: 0.5317 - val_loss: 0.6915 - val_accuracy: 0.5000 - lr: 8.9125e-05
# Epoch 81/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6853 - accuracy: 0.5206 - val_loss: 0.6913 - val_accuracy: 0.4961 - lr: 1.0000e-04
# Epoch 82/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.6819 - accuracy: 0.5295 - val_loss: 0.6907 - val_accuracy: 0.4922 - lr: 1.1220e-04
# Epoch 83/120
# 8/8 [==============================] - 12s 1s/step - loss: 0.6827 - accuracy: 0.5306 - val_loss: 0.6891 - val_accuracy: 0.4883 - lr: 1.2589e-04
# Epoch 84/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.6807 - accuracy: 0.5339 - val_loss: 0.6877 - val_accuracy: 0.4883 - lr: 1.4125e-04
# Epoch 85/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6762 - accuracy: 0.5395 - val_loss: 0.6836 - val_accuracy: 0.4688 - lr: 1.5849e-04
# Epoch 86/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6744 - accuracy: 0.5417 - val_loss: 0.6738 - val_accuracy: 0.4844 - lr: 1.7783e-04
# Epoch 87/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6739 - accuracy: 0.5339 - val_loss: 0.6601 - val_accuracy: 0.5508 - lr: 1.9953e-04
# Epoch 88/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.6607 - accuracy: 0.5654 - val_loss: 0.6293 - val_accuracy: 0.6602 - lr: 2.2387e-04
# Epoch 89/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.6299 - accuracy: 0.6696 - val_loss: 0.4617 - val_accuracy: 0.8633 - lr: 2.5119e-04
# Epoch 90/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.4858 - accuracy: 0.8443 - val_loss: 0.3585 - val_accuracy: 0.8672 - lr: 2.8184e-04
# Epoch 91/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.3970 - accuracy: 0.8788 - val_loss: 0.3544 - val_accuracy: 0.8398 - lr: 3.1623e-04
# Epoch 92/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.3189 - accuracy: 0.8999 - val_loss: 0.4008 - val_accuracy: 0.8320 - lr: 3.5481e-04
# Epoch 93/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.2423 - accuracy: 0.9277 - val_loss: 0.4962 - val_accuracy: 0.8320 - lr: 3.9811e-04
# Epoch 94/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.2893 - accuracy: 0.9055 - val_loss: 0.6608 - val_accuracy: 0.8398 - lr: 4.4668e-04
# Epoch 95/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.1412 - accuracy: 0.9555 - val_loss: 0.8605 - val_accuracy: 0.8281 - lr: 5.0119e-04
# Epoch 96/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.1193 - accuracy: 0.9566 - val_loss: 0.9815 - val_accuracy: 0.8320 - lr: 5.6234e-04
# Epoch 97/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.0808 - accuracy: 0.9677 - val_loss: 1.3596 - val_accuracy: 0.7891 - lr: 6.3096e-04
# Epoch 98/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.0782 - accuracy: 0.9700 - val_loss: 1.3145 - val_accuracy: 0.8320 - lr: 7.0795e-04
# Epoch 99/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.0775 - accuracy: 0.9700 - val_loss: 1.4093 - val_accuracy: 0.8320 - lr: 7.9433e-04
# Epoch 100/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.0884 - accuracy: 0.9633 - val_loss: 1.4718 - val_accuracy: 0.8125 - lr: 8.9125e-04
# Epoch 101/120
# 8/8 [==============================] - 9s 1s/step - loss: 0.0342 - accuracy: 0.9878 - val_loss: 1.5496 - val_accuracy: 0.8359 - lr: 0.0010
# Epoch 102/120
# 8/8 [==============================] - 12s 2s/step - loss: 0.0234 - accuracy: 0.9933 - val_loss: 1.2448 - val_accuracy: 0.8828 - lr: 0.0011
# Epoch 103/120
# 8/8 [==============================] - 13s 2s/step - loss: 0.0685 - accuracy: 0.9711 - val_loss: 1.8158 - val_accuracy: 0.8242 - lr: 0.0013
# Epoch 104/120
# 8/8 [==============================] - 12s 2s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 2.0251 - val_accuracy: 0.8555 - lr: 0.0014
# Epoch 105/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.0836 - accuracy: 0.9655 - val_loss: 0.5194 - val_accuracy: 0.8086 - lr: 0.0016
# Epoch 106/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.1261 - accuracy: 0.9433 - val_loss: 1.7590 - val_accuracy: 0.8398 - lr: 0.0018
# Epoch 107/120
# 8/8 [==============================] - 12s 1s/step - loss: 0.4701 - accuracy: 0.9066 - val_loss: 0.3446 - val_accuracy: 0.9023 - lr: 0.0020
# Epoch 108/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.5306 - accuracy: 0.8665 - val_loss: 1.2277 - val_accuracy: 0.8086 - lr: 0.0022
# Epoch 109/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.0548 - accuracy: 0.9867 - val_loss: 1.1001 - val_accuracy: 0.8789 - lr: 0.0025
# Epoch 110/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.0092 - accuracy: 0.9989 - val_loss: 1.9106 - val_accuracy: 0.8516 - lr: 0.0028
# Epoch 111/120
# 8/8 [==============================] - 12s 1s/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 1.5126 - val_accuracy: 0.8945 - lr: 0.0032
# Epoch 112/120
# 8/8 [==============================] - 12s 2s/step - loss: 0.9991 - accuracy: 0.8276 - val_loss: 0.6255 - val_accuracy: 0.8555 - lr: 0.0035
# Epoch 113/120
# 8/8 [==============================] - 12s 1s/step - loss: 0.0773 - accuracy: 0.9755 - val_loss: 1.6372 - val_accuracy: 0.8633 - lr: 0.0040
# Epoch 114/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.4996 - accuracy: 0.9244 - val_loss: 0.8874 - val_accuracy: 0.8516 - lr: 0.0045
# Epoch 115/120
# 8/8 [==============================] - 9s 1s/step - loss: 4.3094 - accuracy: 0.7753 - val_loss: 7.2306 - val_accuracy: 0.7227 - lr: 0.0050
# Epoch 116/120
# 8/8 [==============================] - 10s 1s/step - loss: 1.5646 - accuracy: 0.7820 - val_loss: 2.9171 - val_accuracy: 0.7656 - lr: 0.0056
# Epoch 117/120
# 8/8 [==============================] - 12s 1s/step - loss: 0.1152 - accuracy: 0.9678 - val_loss: 1.3069 - val_accuracy: 0.8945 - lr: 0.0063
# Epoch 118/120
# 8/8 [==============================] - 11s 1s/step - loss: 0.0699 - accuracy: 0.9689 - val_loss: 1.7145 - val_accuracy: 0.8906 - lr: 0.0071
# Epoch 119/120
# 8/8 [==============================] - 10s 1s/step - loss: 0.0104 - accuracy: 0.9989 - val_loss: 2.7064 - val_accuracy: 0.8867 - lr: 0.0079
# Epoch 120/120
# 8/8 [==============================] - 11s 1s/step - loss: 3.1331 - accuracy: 0.8776 - val_loss: 131.0464 - val_accuracy: 0.5000 - lr: 0.0089

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-9, 1e-1, 0, 2])
# Out:
# (1e-09, 0.1, 0.0, 2.0)

# %% [markdown]
# ### MODEL

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy'])

history = model.fit(
      train_generator,
      steps_per_epoch=8,  
      epochs=15,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 10s 1s/step - loss: 13.8258 - accuracy: 0.6418 - val_loss: 12.9077 - val_accuracy: 0.7070
# Epoch 2/15
# 8/8 [==============================] - 9s 1s/step - loss: 0.4656 - accuracy: 0.9444 - val_loss: 4.9355 - val_accuracy: 0.8633
# Epoch 3/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.1442 - accuracy: 0.9746 - val_loss: 5.9916 - val_accuracy: 0.8242
# Epoch 4/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.0916 - accuracy: 0.9844 - val_loss: 5.4785 - val_accuracy: 0.8242
# Epoch 5/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.0461 - accuracy: 0.9932 - val_loss: 5.0529 - val_accuracy: 0.8320
# Epoch 6/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.0262 - accuracy: 0.9933 - val_loss: 3.7283 - val_accuracy: 0.8594
# Epoch 7/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.0291 - accuracy: 0.9900 - val_loss: 5.1590 - val_accuracy: 0.8320
# Epoch 8/15
# 8/8 [==============================] - 9s 1s/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 6.0199 - val_accuracy: 0.8203
# Epoch 9/15
# 8/8 [==============================] - 9s 1s/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 4.7976 - val_accuracy: 0.8438
# Epoch 10/15
# 8/8 [==============================] - 9s 1s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 5.4415 - val_accuracy: 0.8320
# Epoch 11/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.7842 - val_accuracy: 0.8828
# Epoch 12/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.0481 - accuracy: 0.9878 - val_loss: 3.4351 - val_accuracy: 0.8633
# Epoch 13/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 4.2362 - val_accuracy: 0.8516
# Epoch 14/15
# 8/8 [==============================] - 10s 1s/step - loss: 6.4769e-04 - accuracy: 1.0000 - val_loss: 4.5240 - val_accuracy: 0.8438
# Epoch 15/15
# 8/8 [==============================] - 10s 1s/step - loss: 4.3419e-04 - accuracy: 1.0000 - val_loss: 4.6676 - val_accuracy: 0.8438

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
accuracy=history.history['accuracy']
val_accuracy=history.history['val_accuracy']


epochs=range(len(val_accuracy)) # Get number of epochs

#------------------------------------------------
# Plot MAE and Loss
#------------------------------------------------
plt.plot(epochs, accuracy, 'r')
plt.plot(epochs, val_accuracy, 'b')

plt.title('accuracy and val_accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["accuracy", "val_accuracy"])

plt.figure()

# %% [markdown]
# Below you can see how the characteristics of each image vary

# %%
import numpy as np
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Prepare a random input image from the training set.
horse_img_files = [os.path.join(train_horse_dir, f) for f in train_horse_names]
human_img_files = [os.path.join(train_human_dir, f) for f in train_human_names]
img_path = random.choice(horse_img_files + human_img_files)

img = load_img(img_path, target_size=(150, 150))  # this is a PIL image
x = img_to_array(img)  # Numpy array with shape (300, 300, 3)
x = x.reshape((1,) + x.shape)  # Numpy array with shape (1, 300, 300, 3)

# Scale by 1/255
x /= 255

# Run the image through the network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so you can have them as part of the plot
layer_names = [layer.name for layer in model.layers[1:]]

# Display the representations
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  if len(feature_map.shape) == 4:

    # Just do this for the conv / maxpool layers, not the fully-connected layers
    n_features = feature_map.shape[-1]  # number of features in feature map

    # The feature map has shape (1, size, size, n_features)
    size = feature_map.shape[1]
    
    # Tile the images in this matrix
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      x = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
    
      # Tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# 1/1 [==============================] - 0s 73ms/step
# <ipython-input-46-ff1447792917>:45: RuntimeWarning: invalid value encountered in true_divide
#   x /= x.std()

# %% [markdown]
# In order to evaluate the model, the image below is passed through the model and as can be seen, it was correctly classified.

# %%
path = 'da.jpg' 
img = mpimg.imread(path)
plt.imshow(img)

# %%
import numpy as np
#from google.colab import files
from keras.preprocessing import image

# predicting images
path = 'da.jpg' 
img = tf.keras.utils.load_img(path, target_size=(150, 150))
x = tf.keras.utils.img_to_array(img)
x /= 255
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images, batch_size=10)
print(classes[0])

if classes[0]>0.5:
    print(path + " is a human")
else:
    print(path + " is a horse")
# Out:
# 1/1 [==============================] - 0s 24ms/step
# [9.804666e-05]
# da.jpg is a horse
